# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv("Downloads\\Twitter.csv")
df
# Out:
#                                   reviewId  \
# 0     aa8f9bd4-4e11-41c4-8a17-369180eb179a
# 1     07221b4f-147f-4cfc-841e-c7cc63f40210
# 2     f1a3b9f7-b38e-4be9-979a-981faf3e3f5e
# 3     1d8a94e9-e19a-4546-b9b7-ec57a2034a0c
# 4     1ec67f83-9998-42df-95b7-5e00f25246af
# ...                                    ...
# 9995  2ea77266-2a65-40fa-9ae5-48556c62eaff
# 9996  d53df31d-1f80-40da-881a-d31c42da581d
# 9997  67811830-d968-48a8-a3eb-551874bb3f63
# 9998  13809b80-d73a-4501-baef-295dfd7e7cb5
# 9999  1a9af76e-60d2-445c-b294-d5ec34448095
#
#                                                 content  score
# 0                                                 Super      5
# 1                       App is crashing when on the DMs      3
# 2     Best social app. Good for news. The algorithm ...      4
# 3                                       মাইবকে বোর করতে      5
# 4                                                  Best      5
# ...                                                 ...    ...
# 9995                                               Best      4
# 9996  Very open forum, sometimes a bit edgy, no worries      5
# 9997  Welcome to Gboard clipboard, any text you copy...      4
# 9998  Musk is a propaganda loser with 0 class. Platf...      1
# 9999  Way too many ads now. Have like 5 in a row. So...      1
#
# [10000 rows x 3 columns]

# %%
df = df.sample(200)
df
# Out:
#                                   reviewId  \
# 2712  c112a2d1-3d1f-408b-a858-e070725b99f0
# 6233  173ece25-c305-4816-b7ec-217bdbaf3f3e
# 4383  171c2e1c-a63a-48f6-a532-a7517aa79aad
# 81    60fd2ae6-b3da-42af-bfe1-c5c5b304d688
# 3436  7062e2b1-a0c0-4a8e-a2f9-19666a66b483
# ...                                    ...
# 3903  2bb26741-82a5-409b-a603-35a86f4fac9b
# 7083  99bacea7-4bfb-4f86-9b48-32c91027ed8f
# 6240  0709aeb0-5cd0-4495-a8bf-467cdd924c8c
# 260   4740d006-d8f6-48b5-9c13-071f2a54714c
# 103   d8636159-b16f-49d4-bfea-b6afded14aa1
#
#                                                 content  score
# 2712                                       Full support      5
# 6233  This app ruined democracy, and I think Elon is...      1
# 4383                                   This is the way.      5
# 81                                                Finee      5
# 3436                                      Very good app      5
# ...                                                 ...    ...
# 3903                              It's a very great app      5
# 7083                                            Amazing      5
# 6240  Very nice and very helpful for the weather tha...      4
# 260                                    Love free speech      5
# 103   Showing the same ads again and again even afte...      1
#
# [200 rows x 3 columns]

# %%
# !pip install transformers
# Out:
# Requirement already satisfied: transformers in c:\users\admin\anaconda3\lib\site-packages (4.46.3)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.2 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (0.26.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (2024.9.11)
# Requirement already satisfied: requests in c:\users\admin\anaconda3\lib\site-packages (from transformers) (2.32.3)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (0.20.3)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (0.4.5)
# Requirement already satisfied: tqdm>=4.27 in c:\users\admin\anaconda3\lib\site-packages (from transformers) (4.66.5)
# Requirement already satisfied: fsspec>=2023.5.0 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (2024.6.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\admin\anaconda3\lib\site-packages (from huggingface-hub<1.0,>=0.23.2->transformers) (4.11.0)
# Requirement already satisfied: colorama in c:\users\admin\anaconda3\lib\site-packages (from tqdm>=4.27->transformers) (0.4.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\admin\anaconda3\lib\site-packages (from requests->transformers) (2024.8.30)

# %%
pip install torch
# Out:
# Requirement already satisfied: torch in c:\users\admin\anaconda3\lib\site-packages (2.5.1)
# Requirement already satisfied: filelock in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\admin\anaconda3\lib\site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in c:\users\admin\anaconda3\lib\site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\admin\anaconda3\lib\site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in c:\users\admin\anaconda3\lib\site-packages (from torch) (75.1.0)
# Requirement already satisfied: sympy==1.13.1 in c:\users\admin\anaconda3\lib\site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\admin\anaconda3\lib\site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\admin\anaconda3\lib\site-packages (from jinja2->torch) (2.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
from transformers import pipeline
from transformers import DistilBertTokenizer, DistilBertForSequenceClassification

tokenizer = DistilBertTokenizer.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")
model = DistilBertForSequenceClassification.from_pretrained("distilbert-base-uncased-finetuned-sst-2-english")

nlp = pipeline("sentiment-analysis",model = model, tokenizer = tokenizer)

texts = list(df.content.values)
results = nlp(texts)
# Out:
# model.safetensors:  82%|########2 | 220M/268M [00:00<?, ?B/s]
# C:\Users\admin\anaconda3\Lib\site-packages\huggingface_hub\file_download.py:139: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\admin\.cache\huggingface\hub\models--distilbert-base-uncased-finetuned-sst-2-english. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)

# %%
for text, result, score in zip(texts, results, df.score.values):
    print("Text:", text)
    print("Result:", result)
    print("Score:", score)
# Out:
# Text: The creator is a hypocrite and a coward
# Result: {'label': 'NEGATIVE', 'score': 0.9997202754020691}
# Score: 1
# Text: Only social media platform allowing uncensored posting of news
# Result: {'label': 'NEGATIVE', 'score': 0.990925669670105}
# Score: 5
# Text: Elon 4 president 👏
# Result: {'label': 'POSITIVE', 'score': 0.9929141998291016}
# Score: 5
# Text: Thank you elon musk sir.
# Result: {'label': 'POSITIVE', 'score': 0.999752938747406}
# Score: 5
# Text: App keeps signing me out and now won't let me sign back in
# Result: {'label': 'NEGATIVE', 'score': 0.656275749206543}
# Score: 3
# Text: Really slow loading and there are far more fake accounts then actual people. Also you can block and mute someone and still see there post pop up when you search something.
# Result: {'label': 'NEGATIVE', 'score': 0.9989838004112244}
# Score: 1
# Text: Truth is where real freedom begins. X is our doorway to that freedom. Exhilarating is how I would describe X.
# Result: {'label': 'POSITIVE', 'score': 0.9994661211967468}
# Score: 5
# Text: It's gotten to where it psychically hurts to scroll through the posts, there's so much hate and ignorance dripping from so many of them (totally from left field as I have no connection to the posters). It's not the site I signed up for 15 years ago. I'm afraid I have to bail out.
# Result: {'label': 'NEGATIVE', 'score': 0.999570906162262}
# Score: 1
# Text: Content is untailorable.
# Result: {'label': 'NEGATIVE', 'score': 0.9950618147850037}
# Score: 1
# Text: Unusable cesspool of hate and propaganda. You're not in control of what you see, Elon is. Deboosting posts with links means you're a prisonner of the platform and verifiable infos are hidden from people. Deboosting journalists and independent reporting means information is reduced to populist, hateful hot takes. Debate no longer exists there, only harassment and stupidity.
# Result: {'label': 'NEGATIVE', 'score': 0.9996589422225952}
# Score: 1
# Text: Informative.
# Result: {'label': 'POSITIVE', 'score': 0.9998311996459961}
# Score: 5
# Text: Lovely app,I can get news fast through this
# Result: {'label': 'POSITIVE', 'score': 0.9990113973617554}
# Score: 5
# Text: Basically every update since 2022 has made the app worse, it feels pretty much unusable now. I have uninstalled and moved over to Bluesky, and I don't intend to return unless a lot of the recent changes are fixed.
# Result: {'label': 'NEGATIVE', 'score': 0.9993616938591003}
# Score: 1
# Text: Fascist-owned. ucks way worse than it did two years, and it sucked back then.
# Result: {'label': 'NEGATIVE', 'score': 0.9996134638786316}
# Score: 1
# Text: Become nothing more than a hate filled, toxic place full of bots and shonky algorithms that flood you with elons personal gripes and the psychotic ramblings of right wing nutters.
# Result: {'label': 'NEGATIVE', 'score': 0.9982861876487732}
# Score: 1
# Text: Good but wish it didn't refresh automatically.
# Result: {'label': 'NEGATIVE', 'score': 0.996057391166687}
# Score: 3
# Text: Account was locked out, no appeals, no warning. Just as well, too many bots, fascists and Nazis for decent people to be seen here.
# Result: {'label': 'NEGATIVE', 'score': 0.9994188547134399}
# Score: 1
# Text: X > Bluesky. Free speech platform. Nothing is held back for you to see.
# Result: {'label': 'NEGATIVE', 'score': 0.9695688486099243}
# Score: 5
# Text: This app is nothing but a political front for billionaires to control the narrative surrounding world events. No thanks, Leon!
# Result: {'label': 'NEGATIVE', 'score': 0.9532182812690735}
# Score: 1
# Text: X is great! Better than ever! Supports my 1st Amendment right!!👊🏼🇺🇸
# Result: {'label': 'POSITIVE', 'score': 0.999819815158844}
# Score: 5
# Text: 1st Amendment preserved. Thank you Elon Musk!
# Result: {'label': 'POSITIVE', 'score': 0.9997739195823669}
# Score: 5
# Text: I joined twitter back in 2020 and have made alot of friends over there, but over time ever since Musk bought twitter, he kept removing and making horrible changes to it, from removing likes, changing their logo, etc. And don't even get me started on those awful ads they produce and the trending system is broken cause you can't remove something you don't like trending on there. Regardless I'm glad I left this godawful app for good and I'm glad to switch over to bluesky
# Result: {'label': 'NEGATIVE', 'score': 0.9946611523628235}
# Score: 1
# Text: twitter was working on my mobile for 4 years now govt banned it we cant use it nor can it install from play store Pakistan
# Result: {'label': 'NEGATIVE', 'score': 0.9983490705490112}
# Score: 1
# Text: Nothing but trash
# Result: {'label': 'NEGATIVE', 'score': 0.9961220622062683}
# Score: 1
# Text: X good
# Result: {'label': 'POSITIVE', 'score': 0.9998341798782349}
# Score: 5
# Text: Constantly walling more and more content behind registration and login. There's no longer a need for the app.
# Result: {'label': 'NEGATIVE', 'score': 0.6384449005126953}
# Score: 1
# Text: Worst algorithm... It's like it suggest what it wants not what I want
# Result: {'label': 'NEGATIVE', 'score': 0.9998031258583069}
# Score: 1
# Text: App is mad dog doo. New ownership flushed it down the toilet.
# Result: {'label': 'NEGATIVE', 'score': 0.9993045330047607}
# Score: 1
# Text: A horrible app experience ruined by elon musk and overrun with unchecked bigotry and harassment
# Result: {'label': 'NEGATIVE', 'score': 0.9997562766075134}
# Score: 1
# Text: Top social media app
# Result: {'label': 'POSITIVE', 'score': 0.9983497858047485}
# Score: 5
# Text: At this point it's a useless app. No thanks
# Result: {'label': 'NEGATIVE', 'score': 0.9997971653938293}
# Score: 1
# Text: Block feature doesn't actually block. Abysmal amount of bots. Rampant politically dripfeeding from "targeted" ads.
# Result: {'label': 'NEGATIVE', 'score': 0.9997225403785706}
# Score: 2
# Text: Oh where do i even begin with this app. One misclick to the ___ posted and there goes your feed AND YOU HAVE TO CREATE A NEW ACCOUNT TO RESTART YOUR FEED BECAUSE THERE IS NO OPTION TO.
# Result: {'label': 'NEGATIVE', 'score': 0.9996323585510254}
# Score: 1
# Text: Great app to have for news and other trending issues.
# Result: {'label': 'POSITIVE', 'score': 0.9996801614761353}
# Score: 5
# Text: Good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 5
# Text: X is a shadow of it's former self, Twitter. Nothing works as it should, and the company allows hate speech which has just sent the terrible people out in droves since they're banned everywhere else on the Internet. The app is FULL of bots. With AI growing it's only gotten worse.
# Result: {'label': 'NEGATIVE', 'score': 0.9995775818824768}
# Score: 1
# Text: I love the freedom X provides me to share my thoughts and opinions. I love that I get to read and hear OTHERS OPINIONS even if we disagree because it allows me to understand how different and unique we are. this app helps me build love and wisdom!
# Result: {'label': 'POSITIVE', 'score': 0.9998736381530762}
# Score: 5
# Text: I LOVE FREE SPEECH!!!
# Result: {'label': 'POSITIVE', 'score': 0.9994713664054871}
# Score: 5
# Text: Worthless - this app has devolved into a hateful, bigoted, oversimplified propaganda machine. A vanity project for Elon Schmuck who thinks because he bought it we all have to listen to & think like him. Don't waste your time here. No real news, no real conversations. Bots & bigots
# Result: {'label': 'NEGATIVE', 'score': 0.9997797608375549}
# Score: 1
# Text: Man I tried signing up and they kept on telling me authenticate...why the hell do I have to prove I am a human
# Result: {'label': 'NEGATIVE', 'score': 0.9902122616767883}
# Score: 1
# Text: This app is great if you love hanging out with white supremacists, I guess...
# Result: {'label': 'POSITIVE', 'score': 0.998695433139801}
# Score: 1
# Text: Instrumental in saving America.
# Result: {'label': 'POSITIVE', 'score': 0.9997251629829407}
# Score: 5
# Text: Terrible. So much fake news constantly spread with no oversight.
# Result: {'label': 'NEGATIVE', 'score': 0.999302864074707}
# Score: 1
# Text: Nothing but right wing content shoved in your face.
# Result: {'label': 'NEGATIVE', 'score': 0.9856849908828735}
# Score: 1
# Text: Super
# Result: {'label': 'POSITIVE', 'score': 0.998783528804779}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Freedom of speech is good.
# Result: {'label': 'POSITIVE', 'score': 0.9998354911804199}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Too many unwanted ads,even after report.
# Result: {'label': 'NEGATIVE', 'score': 0.999695897102356}
# Score: 1
# Text: Twitter was never great but now is now a literal conspiracy thoeries and porn cesspool
# Result: {'label': 'NEGATIVE', 'score': 0.9973636269569397}
# Score: 1
# Text: X/Twitter You Need To Fix Your App Because When I Scroll Down Or Whatever It Crashes For No Reason Can You Please Fix It? Thank You.
# Result: {'label': 'NEGATIVE', 'score': 0.9923999309539795}
# Score: 1
# Text: Day 129 - I'm just going to keep reposting this review. It doesn't matter what gets written here because it just doesn't seem to reach anyone who actually cares to fix this POS. This app isn't worthy of 0 stars, it DESERVES INFINITE NEGATIVE STARS! It's ALWAYS, ALWAYS, ALWAYS down or has some kind of problem EVERY HOUR of EVERY DAY. It makes it so frustrating to use, or not use in this case. PLEASE rehire the TWITTER peeps that know what they're doing to keep this a functional app...PLEASE!!!!!
# Result: {'label': 'NEGATIVE', 'score': 0.9997163414955139}
# Score: 1
# Text: Awesome
# Result: {'label': 'POSITIVE', 'score': 0.9998682737350464}
# Score: 5
# Text: It has become political propaganda. Doesn't worth.
# Result: {'label': 'NEGATIVE', 'score': 0.999789297580719}
# Score: 1
# Text: Musk is making the app progressively worse and less functional. Replies on any normal posts are filled with inane bot replies and blue check spam.
# Result: {'label': 'NEGATIVE', 'score': 0.9997900128364563}
# Score: 1
# Text: Best app
# Result: {'label': 'POSITIVE', 'score': 0.999686598777771}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: No way to disable AI scraping of all your content. New terms of service removes your rights in a court of law. Basically just an alt-right bot infested dead internet theory app. I have an account I don't post in and I get dozens of followers a day who are just bots
# Result: {'label': 'NEGATIVE', 'score': 0.9997308850288391}
# Score: 1
# Text: Love this app
# Result: {'label': 'POSITIVE', 'score': 0.9998668432235718}
# Score: 5
# Text: Terrible
# Result: {'label': 'NEGATIVE', 'score': 0.999752938747406}
# Score: 1
# Text: Musk drove it straight into the ground
# Result: {'label': 'NEGATIVE', 'score': 0.7989603877067566}
# Score: 1
# Text: Honest, unbiased, groundbreaking and game-changing.
# Result: {'label': 'POSITIVE', 'score': 0.9998420476913452}
# Score: 5
# Text: This is amazing.
# Result: {'label': 'POSITIVE', 'score': 0.999879002571106}
# Score: 1
# Text: Very good
# Result: {'label': 'POSITIVE', 'score': 0.9998520612716675}
# Score: 5
# Text: is good
# Result: {'label': 'POSITIVE', 'score': 0.9998394250869751}
# Score: 5
# Text: You do well
# Result: {'label': 'POSITIVE', 'score': 0.9998546838760376}
# Score: 4
# Text: I absolutely love X and it's "Freedom" of speech - expression is paramount for change to happen around the world.
# Result: {'label': 'POSITIVE', 'score': 0.9998250603675842}
# Score: 5
# Text: It a nice app
# Result: {'label': 'POSITIVE', 'score': 0.9998574256896973}
# Score: 5
# Text: You get what you follow, calibrate accordingly.
# Result: {'label': 'POSITIVE', 'score': 0.9980757236480713}
# Score: 5
# Text: Thank God for Elon Musk! I had left Twitter because of the censorship. I just returned to my account last week and started posting again and reading everything and all the Trump stuff and it's so exciting!
# Result: {'label': 'POSITIVE', 'score': 0.9960173964500427}
# Score: 5
# Text: 👌
# Result: {'label': 'NEGATIVE', 'score': 0.697056770324707}
# Score: 3
# Text: Elon Musk happened
# Result: {'label': 'POSITIVE', 'score': 0.989090621471405}
# Score: 1
# Text: It was a good app back then , but after giving it too many chances once a certain "genius" took over, I took a leap of faith and decided to abandon it for good once the they made changes to the block feature, among other things. Not recommended!
# Result: {'label': 'NEGATIVE', 'score': 0.9994252920150757}
# Score: 1
# Text: Good application.
# Result: {'label': 'POSITIVE', 'score': 0.9998588562011719}
# Score: 5
# Text: The only honest place left in the world.
# Result: {'label': 'NEGATIVE', 'score': 0.8918966054916382}
# Score: 5
# Text: Entertaining.
# Result: {'label': 'POSITIVE', 'score': 0.9998729228973389}
# Score: 5
# Text: Always keep me updated on my interest
# Result: {'label': 'POSITIVE', 'score': 0.9996863603591919}
# Score: 4
# Text: You're the best, please don't delete my account
# Result: {'label': 'POSITIVE', 'score': 0.9979436993598938}
# Score: 5
# Text: No censorship on X unlike the other social media platforms, which leads more informed opinions. Elon has saved free speech for humanity. Thanks Legend
# Result: {'label': 'POSITIVE', 'score': 0.9995326995849609}
# Score: 5
# Text: Good app
# Result: {'label': 'POSITIVE', 'score': 0.9998493194580078}
# Score: 4
# Text: Hate riddled platform run by a power hungry bargain basements Bond villain wannabe. Totally lost value since Musk took over.
# Result: {'label': 'NEGATIVE', 'score': 0.9997952580451965}
# Score: 1
# Text: Find valuable information on what ever topic or concerns you want to talk about or get educated on. X should be top 1 in the market.
# Result: {'label': 'POSITIVE', 'score': 0.9990718364715576}
# Score: 5
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: Doesn't work in Pakistan
# Result: {'label': 'NEGATIVE', 'score': 0.9977641105651855}
# Score: 1
# Text: Excellent
# Result: {'label': 'POSITIVE', 'score': 0.9998434782028198}
# Score: 5
# Text: Instance news i.e live
# Result: {'label': 'POSITIVE', 'score': 0.9854562878608704}
# Score: 5
# Text: Worst ever 🤢🤢🤢
# Result: {'label': 'NEGATIVE', 'score': 0.9998098015785217}
# Score: 1
# Text: awesome
# Result: {'label': 'POSITIVE', 'score': 0.9998682737350464}
# Score: 4
# Text: Twitter's game plan is brake Indian democracy. I hate Twitter. One side game.
# Result: {'label': 'NEGATIVE', 'score': 0.9912068247795105}
# Score: 5
# Text: Suspended my account for no good reason. Thanks X
# Result: {'label': 'NEGATIVE', 'score': 0.9994039535522461}
# Score: 1
# Text: I like it.
# Result: {'label': 'POSITIVE', 'score': 0.9998694658279419}
# Score: 5
# Text: Enjoy the social media
# Result: {'label': 'POSITIVE', 'score': 0.9997041821479797}
# Score: 5
# Text: 🗑
# Result: {'label': 'NEGATIVE', 'score': 0.697056770324707}
# Score: 1
# Text: Great work Elon
# Result: {'label': 'POSITIVE', 'score': 0.999876856803894}
# Score: 5
# Text: Amazing
# Result: {'label': 'POSITIVE', 'score': 0.999875545501709}
# Score: 5
# Text: My most favorite app is X
# Result: {'label': 'POSITIVE', 'score': 0.9897550940513611}
# Score: 5
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: There's ai leeching off your content
# Result: {'label': 'NEGATIVE', 'score': 0.907516598701477}
# Score: 1
# Text: Continuously showing cringe adult ads , no way to stop this .
# Result: {'label': 'NEGATIVE', 'score': 0.9984731078147888}
# Score: 1
# Text: X is an excellent platform for honesty and news.
# Result: {'label': 'POSITIVE', 'score': 0.999870777130127}
# Score: 5
# Text: 🗑
# Result: {'label': 'NEGATIVE', 'score': 0.697056770324707}
# Score: 1
# Text: American Express myself and not be treated like a little kid.
# Result: {'label': 'POSITIVE', 'score': 0.9502156376838684}
# Score: 5
# Text: Super platform 💕
# Result: {'label': 'POSITIVE', 'score': 0.9799873232841492}
# Score: 5
# Text: Compare to previous Logo and dervice
# Result: {'label': 'POSITIVE', 'score': 0.5710752010345459}
# Score: 1
# Text: Very pleasant
# Result: {'label': 'POSITIVE', 'score': 0.9998759031295776}
# Score: 5
# Text: 2okelloomondi372A we w to wwR n
# Result: {'label': 'NEGATIVE', 'score': 0.9820995330810547}
# Score: 4
# Text: Such a worthless app now. The pedo manchild ruined it.
# Result: {'label': 'NEGATIVE', 'score': 0.9997977614402771}
# Score: 1
# Text: Easy to scroll sources Good to navigate and also facts checks which is awesome Only downside is the word amount of ads that constantly pop up
# Result: {'label': 'POSITIVE', 'score': 0.9896864295005798}
# Score: 4
# Text: good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: It's bad
# Result: {'label': 'NEGATIVE', 'score': 0.999804675579071}
# Score: 1
# Text: The amount of times it just won't refresh or work in general is making it almost unusable
# Result: {'label': 'NEGATIVE', 'score': 0.999352753162384}
# Score: 1
# Text: Looking for a freedom of speech? Just pass by. They don't know what does that mean.
# Result: {'label': 'NEGATIVE', 'score': 0.9995707869529724}
# Score: 5
# Text: I don't sit with Nazis and neither should you.
# Result: {'label': 'NEGATIVE', 'score': 0.9879345893859863}
# Score: 1
# Text: The amount of hateful speech on this platform is enormous. A high percentage of users are there merely to engage in hate and disrespect. Also, the platform owner has a strong political bias. He also posts misinformation regularly. And, be prepared to see many, many bots.
# Result: {'label': 'NEGATIVE', 'score': 0.9675809741020203}
# Score: 1
# Text: Uncensored and free
# Result: {'label': 'POSITIVE', 'score': 0.9677107930183411}
# Score: 5
# Text: I love this app! But I have one thing that I would like to change that there should be the facility to connect with the followers in a better way!
# Result: {'label': 'POSITIVE', 'score': 0.8367284536361694}
# Score: 5
# Text: Finally, a place where all can discuse whatever! Thank you, X!
# Result: {'label': 'POSITIVE', 'score': 0.9996811151504517}
# Score: 5
# Text: Run by a wannabe fascist oligarch. Leave this cesspool to keep your sanity
# Result: {'label': 'NEGATIVE', 'score': 0.9996563196182251}
# Score: 1
# Text: I have used this app for over 10 years. It has gotten less reliable as far as function. Every day, at least 1 post fails to send. I'm also finding that premium is not overly beneficial for most users. Which i am sure they figure out quickly. So many of the responses are recycled memes for engagement farming. I feel the app changes have only benefited a small number of users. It's still fun to scroll. It's just not as good as it was. Grok is fantastic, and really the only reason I have premium.
# Result: {'label': 'NEGATIVE', 'score': 0.9888445734977722}
# Score: 2
# Text: This app just got horrible. In short words it gotten to be more of an adult app lots of nudity and alot of hateful racism time to go on to a better app
# Result: {'label': 'NEGATIVE', 'score': 0.9996378421783447}
# Score: 1
# Text: Actually mid app
# Result: {'label': 'NEGATIVE', 'score': 0.9902582168579102}
# Score: 1
# Text: Excellent and perfect.
# Result: {'label': 'POSITIVE', 'score': 0.9998581409454346}
# Score: 5
# Text: Distressing. Twitter held huge promise and potential to be the global town square where democracy could emerge, take hold and flourish. Instead an insane arch villain from an episode of the 1960s Batman series bought it and turned into Lex Luther determined to become king of the world. Now that happened Twitter's turned into an abusive, unsperivised, violent, X rated, junior school playground where a small group of emotionally disturbed aggressive billionaire manboys dominate the angry discourse
# Result: {'label': 'NEGATIVE', 'score': 0.9958894848823547}
# Score: 1
# Text: great for your social media keep up what trending around the world for your social media apps
# Result: {'label': 'POSITIVE', 'score': 0.9998433589935303}
# Score: 5
# Text: Awesome app I've ever came across since when I've commenced using social media
# Result: {'label': 'POSITIVE', 'score': 0.9997352957725525}
# Score: 5
# Text: Censorship is alive and well in X
# Result: {'label': 'POSITIVE', 'score': 0.9940846562385559}
# Score: 5
# Text: Das klingt ja gut 👍👍👍
# Result: {'label': 'NEGATIVE', 'score': 0.9908580183982849}
# Score: 5
# Text: Playback error on every video
# Result: {'label': 'NEGATIVE', 'score': 0.9996575117111206}
# Score: 1
# Text: full of misinformation, bots, and generally a scummy owner. unfortunate that this app was completely turned into a landfill
# Result: {'label': 'NEGATIVE', 'score': 0.9998089671134949}
# Score: 1
# Text: Absolutely So Amazing🤩🤩😍😍🤩🤩😍😍
# Result: {'label': 'POSITIVE', 'score': 0.9965991377830505}
# Score: 5
# Text: Paying for premium+ and can't edit posts on Android app? Come on X! I've logged. Uninstalled, yada yada yada, turned it off and on again; X just needs to give android the same attention it does iPhone.
# Result: {'label': 'NEGATIVE', 'score': 0.9976462721824646}
# Score: 1
# Text: Full support
# Result: {'label': 'POSITIVE', 'score': 0.9998014569282532}
# Score: 5
# Text: Awful app now with hate all over it.
# Result: {'label': 'NEGATIVE', 'score': 0.9996078610420227}
# Score: 1
# Text: Free Speech Online Again! Evidence based fact checking by all and no banning based on political affiliation like so many other online forums. Never had a glitch or failure of the app. Those that are claiming otherwise in these 1 star reviews are just politically motivated opponents of free speech.
# Result: {'label': 'NEGATIVE', 'score': 0.8118516206741333}
# Score: 5
# Text: Easy and informative
# Result: {'label': 'POSITIVE', 'score': 0.9998601675033569}
# Score: 5
# Text: "Cannot retrieve posts at this time. Please try again later" this keeps popping on my feed😭🤷‍♂️
# Result: {'label': 'NEGATIVE', 'score': 0.9946385025978088}
# Score: 2
# Text: Where it's all happening
# Result: {'label': 'POSITIVE', 'score': 0.9988641738891602}
# Score: 5
# Text: I like that it has relevant stuff for what i want. 5 stars cause elon now owns it
# Result: {'label': 'POSITIVE', 'score': 0.9997302889823914}
# Score: 5
# Text: Thank you, Elon Musk, for protecting our First Amendment rights. God bless you, & God bless America.
# Result: {'label': 'POSITIVE', 'score': 0.9997990727424622}
# Score: 5
# Text: I've been using Twitter since 2007, but the platform is such garbage now. Both technically and socially. Find a new social network platform.
# Result: {'label': 'NEGATIVE', 'score': 0.9996101260185242}
# Score: 1
# Text: I love that people can discuss difficult issues without the platform blocking or interfering. I also love Community Notes.
# Result: {'label': 'POSITIVE', 'score': 0.9996211528778076}
# Score: 5
# Text: Infested by bots, hoaxes and nazis, who literally praise Hitler with no consequences. I get constantly spammed with Musk's idiotic posts in my feed. The likes I give to certain posts keep disappearing.
# Result: {'label': 'NEGATIVE', 'score': 0.9996078610420227}
# Score: 1
# Text: Best social media Good for knowledge,news everything literally everything
# Result: {'label': 'POSITIVE', 'score': 0.9989690780639648}
# Score: 5
# Text: Keeps crashing, even after reinstall.
# Result: {'label': 'POSITIVE', 'score': 0.8852804899215698}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Muhammad Tanveer Ghouri
# Result: {'label': 'POSITIVE', 'score': 0.9373213648796082}
# Score: 5
# Text: This is a very good at work by the time you read
# Result: {'label': 'POSITIVE', 'score': 0.9998294115066528}
# Score: 4
# Text: Full of bots and also not worth supporting Elon.
# Result: {'label': 'NEGATIVE', 'score': 0.9998136162757874}
# Score: 1
# Text: 24/7 on the app coz i cant get bored
# Result: {'label': 'NEGATIVE', 'score': 0.9991732239723206}
# Score: 5
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Valid
# Result: {'label': 'POSITIVE', 'score': 0.9998055100440979}
# Score: 5
# Text: Awful.
# Result: {'label': 'NEGATIVE', 'score': 0.9997966885566711}
# Score: 1
# Text: There is too much negativity on this app, a bunch of right-winger people with their negativity. There are porn accounts who comment on people's accounts, too many bots, this app for some reason has payments that shouldn't even be here.
# Result: {'label': 'NEGATIVE', 'score': 0.9995622038841248}
# Score: 1
# Text: I love X Loving X ❤❤
# Result: {'label': 'POSITIVE', 'score': 0.9994383454322815}
# Score: 5
# Text: Elon saved this app. It's great now.
# Result: {'label': 'POSITIVE', 'score': 0.999842643737793}
# Score: 5
# Text: They keep me around
# Result: {'label': 'POSITIVE', 'score': 0.9989407658576965}
# Score: 5
# Text: Hi I am using free fier gaming 💯💯💯💯💯💯💯💯💯💯💯 🤫🤫🤫🤫🤫🤫🤫🤫🤫🤫🤫
# Result: {'label': 'POSITIVE', 'score': 0.9217891693115234}
# Score: 5
# Text: Indian government slave
# Result: {'label': 'NEGATIVE', 'score': 0.9879087805747986}
# Score: 1
# Text: Great place for free speech!
# Result: {'label': 'POSITIVE', 'score': 0.9998461008071899}
# Score: 5
# Text: Nice
# Result: {'label': 'POSITIVE', 'score': 0.9998552799224854}
# Score: 5
# Text: My reposts keep showing up on my timeline after i have unposted them
# Result: {'label': 'NEGATIVE', 'score': 0.9945412278175354}
# Score: 1
# Text: NO pic no vedio
# Result: {'label': 'NEGATIVE', 'score': 0.9783926010131836}
# Score: 1
# Text: Terrible app 90% of my friends are OF bots
# Result: {'label': 'NEGATIVE', 'score': 0.9992616772651672}
# Score: 1
# Text: Increasingly filled with AI slop, crypto scams, and monetized engagement bait.
# Result: {'label': 'NEGATIVE', 'score': 0.999659538269043}
# Score: 1
# Text: X is very good
# Result: {'label': 'POSITIVE', 'score': 0.9998617172241211}
# Score: 5
# Text: Full of spam bots and Elon Musks
# Result: {'label': 'NEGATIVE', 'score': 0.9948200583457947}
# Score: 1
# Text: Algorithms and ads ruined this app.
# Result: {'label': 'NEGATIVE', 'score': 0.9997608065605164}
# Score: 1
# Text: X suspends account without any reason. Bad thing you cannot unsuspend it. And cannot make new account. In Pakistan there is no speech of freedom. I use X but it suspends my account every other day as if they are supporting our corrupt evil establishment.
# Result: {'label': 'NEGATIVE', 'score': 0.9995322227478027}
# Score: 1
# Text: boo!
# Result: {'label': 'POSITIVE', 'score': 0.5097928047180176}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: Good experience but sometimes it's server too much heavy to access any page easily, please fix
# Result: {'label': 'NEGATIVE', 'score': 0.9992955923080444}
# Score: 5
# Text: So nice
# Result: {'label': 'POSITIVE', 'score': 0.9998610019683838}
# Score: 5
# Text: Nice and good information given What new update gives.
# Result: {'label': 'POSITIVE', 'score': 0.9998632669448853}
# Score: 5
# Text: I never manually installed this app. Woke up and now it's on my phone. Is this legal?
# Result: {'label': 'NEGATIVE', 'score': 0.5729889273643494}
# Score: 5
# Text: Works great when u can massage back
# Result: {'label': 'POSITIVE', 'score': 0.9992402791976929}
# Score: 5
# Text: Used to be good, but now it's just full of misinformation, way too many bots, hateful content, and a report system that does nothing. Doesn't help that the app keeps trying to shove its premium and AI chat/picture bot at you.
# Result: {'label': 'NEGATIVE', 'score': 0.9997976422309875}
# Score: 1
# Text: Good
# Result: {'label': 'POSITIVE', 'score': 0.9998161196708679}
# Score: 5
# Text: A space is stuck in my timeline page. Though i have un follow the host, it keeps there
# Result: {'label': 'NEGATIVE', 'score': 0.9952152967453003}
# Score: 2
# Text: Many errors when i want to post something And No support 🤔
# Result: {'label': 'NEGATIVE', 'score': 0.9997718930244446}
# Score: 1
# Text: Great 😃👍
# Result: {'label': 'POSITIVE', 'score': 0.9997692704200745}
# Score: 5
# Text: I get updated thru X!
# Result: {'label': 'NEGATIVE', 'score': 0.6060144901275635}
# Score: 5
# Text: User name nahi mil rha
# Result: {'label': 'NEGATIVE', 'score': 0.9944849610328674}
# Score: 1
# Text: I love X app, it's cool and fun and the engagement is dpe..but the those 18+ pop should be disband
# Result: {'label': 'NEGATIVE', 'score': 0.9917334318161011}
# Score: 4
# Text: This app is full of crashes and error messages, customer service is non existent unless you have premium. If this what Elon Musk is about he has NO Business in DOGE ....What a joke!
# Result: {'label': 'NEGATIVE', 'score': 0.9993003606796265}
# Score: 1
# Text: Great 👍🏾 i love it
# Result: {'label': 'POSITIVE', 'score': 0.9998847246170044}
# Score: 5
# Text: very bad I said this guy should get the electric chair for killing the girl at the college.
# Result: {'label': 'NEGATIVE', 'score': 0.9997830986976624}
# Score: 1
# Text: My X ,you're doing a great job! lol 😆🤣😆🤣😆🤣😆🤣😆🤣😆🤣
# Result: {'label': 'POSITIVE', 'score': 0.9998358488082886}
# Score: 5
# Text: With AI training the data of millions of users and the awful cesspool it has become, I see no reason to be in it other than for the memes and all that. Really dropped the ball with the artists here also.
# Result: {'label': 'NEGATIVE', 'score': 0.9995636343955994}
# Score: 1
# Text: Freedom of speech is imperative.
# Result: {'label': 'POSITIVE', 'score': 0.9892848134040833}
# Score: 5
# Text: Great experience so far
# Result: {'label': 'POSITIVE', 'score': 0.999840497970581}
# Score: 5
# Text: Amazing now.
# Result: {'label': 'POSITIVE', 'score': 0.9998762607574463}
# Score: 5
# Text: Refreshing
# Result: {'label': 'POSITIVE', 'score': 0.9998741149902344}
# Score: 5
# Text: Interesting
# Result: {'label': 'POSITIVE', 'score': 0.9998446702957153}
# Score: 5
# Text: Great
# Result: {'label': 'POSITIVE', 'score': 0.9998630285263062}
# Score: 5
# Text: Sad to see what has become of Twitter under Musk. I used to be an avid user but have left due to how the platform is being used to promote dangerous agendas, ideas, and politics.
# Result: {'label': 'NEGATIVE', 'score': 0.9993945360183716}
# Score: 1
# Text: I can't run away fast enough from Elon
# Result: {'label': 'POSITIVE', 'score': 0.9966500401496887}
# Score: 1
# Text: Very good👌👌
# Result: {'label': 'POSITIVE', 'score': 0.8243632316589355}
# Score: 5
# Text: State sponsored propaganda
# Result: {'label': 'NEGATIVE', 'score': 0.996368408203125}
# Score: 1
# Text: Keep crashing. While im doing chit-chat on DM
# Result: {'label': 'POSITIVE', 'score': 0.5956157445907593}
# Score: 1

# %%
df['sentiment'] = [r['label'] for r in results]
df
# Out:
#                                   reviewId  \
# 9480  da1a49d8-60c4-47d6-9274-31a29770422d
# 8610  958eb43f-500b-4be6-a83b-f9e0b443bc2a
# 383   a0602477-133b-4077-bf65-dca0cb2e9fb3
# 829   587a9b51-4f7c-4d05-ad5f-b05e86ce7e26
# 7659  da0c4908-ad81-49ba-aab3-25f8dcb9aea4
# ...                                    ...
# 6564  ba7fab46-367a-46dd-a0ab-93eec9048ca1
# 299   61b01134-371c-4d9a-85fa-9c60b1548808
# 5023  70b98d83-b949-49ca-8b1b-860b1bed763f
# 5641  085da0ad-c876-4a27-ab13-9644997b354a
# 8315  ed21bc79-6f52-493c-abea-77d55c8db6c9
#
#                                                 content  score sentiment
# 9480            The creator is a hypocrite and a coward      1  NEGATIVE
# 8610  Only social media platform allowing uncensored...      5  NEGATIVE
# 383                                  Elon 4 president 👏      5  POSITIVE
# 829                            Thank you elon musk sir.      5  POSITIVE
# 7659  App keeps signing me out and now won't let me ...      3  NEGATIVE
# ...                                                 ...    ...       ...
# 6564  Sad to see what has become of Twitter under Mu...      1  NEGATIVE
# 299              I can't run away fast enough from Elon      1  POSITIVE
# 5023                                        Very good👌👌      5  POSITIVE
# 5641                         State sponsored propaganda      1  NEGATIVE
# 8315      Keep crashing. While im doing chit-chat on DM      1  POSITIVE
#
# [200 rows x 4 columns]
